# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from IPython.display import YouTubeVideo
# For more information about Covariaance and Correlation
# Check out these great videos!
# Video credit: Brandon Foltz.

#CoVariance
YouTubeVideo('xGbpuFNR1ME')

# %%
#Now lets check correlation and covariance on some stock prices!

#Pandas can get info off the web
#import pandas.io.data as pdweb
#http://pandas.pydata.org/pandas-docs/stable/remote_data.html
import pandas_datareader as pdweb
import pandas_datareader.data as web
#from pandas_datareader import data, wb
#Set datetime for date input
import datetime

start = datetime.datetime(2016, 1, 29)
end = datetime.datetime(2016, 10, 7)
f = web.DataReader("PAAS", 'yahoo', start, end)

#f.head

#Get the closing prices
#AttributeError: module 'pandas_datareader' has no attribute 'get_data_yahoo'
#prices = pdweb.get_data_yahoo(['PAAS','ELD','BP'], 
#                               start=datetime.datetime(2010, 1, 1), 
#                               end=datetime.datetime(2013, 1, 1))['Adj Close']
#Show preview

#prices.head()

# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import pandas_datareader as pdweb
import pandas_datareader.data as web
import datetime

# The silver miners stocks we'll use for this analysis
tech_list = ['PAAS','AG']

# Set up End and Start times for data grab
start = datetime.datetime(2016, 1, 29)
end = datetime.datetime(2016, 10, 7)


#For loop for grabing yahoo finance data and setting as a dataframe

for stock in tech_list:   
    # Set DataFrame as the Stock Ticker
    #PAAS = web.DataReader("PAAS",'yahoo',start,end)
    globals()[stock] = web.DataReader(stock,'yahoo',start,end)


# Let's see a historical view of the closing price
#PAA
PAAS['Adj Close'].plot(legend=True,figsize=(10,4))
#First Majestic 
AG['Adj Close'].plot(legend=True,figsize=(10,4))
#amazon = web.get_quote_yahoo('PAAS')

# %%
closing_df = web.DataReader(['PAAS','AG'],'yahoo',start,end)['Adj Close']
# Let's take a quick look
closing_df.head()
# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
# Comparing Google to itself should show a perfectly linear relationship
sns.jointplot('PAAS','AG',tech_rets,kind='scatter',color='seagreen')
